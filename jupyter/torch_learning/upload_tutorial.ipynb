# %%
import torch 
from torchvision.models import models
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import torch
# ----> 2 from torchvision.models import models
#
# ImportError: cannot import name 'models' from 'torchvision.models' (C:\Users\YYY\miniconda3\envs\torch_env\lib\site-packages\torchvision\models\__init__.py)
